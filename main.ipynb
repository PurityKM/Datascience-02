# %% [markdown]
# # DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
sample = pd.read_csv('sample_corr.csv')
sample
# Out:
#            x         y
# 0   1.105722  1.320945
# 1   1.158193  1.480131
# 2   1.068022  1.173479
# 3   1.131291  1.294706
# 4   1.125997  1.293024
# 5   1.037332  0.977393
# 6   1.051670  1.040798
# 7   0.971699  0.977604
# 8   1.102914  1.127956
# 9   1.164161  1.431070
# 10  1.161464  1.344481
# 11  1.080161  1.191159
# 12  0.996044  0.997308
# 13  1.143305  1.412850
# 14  1.062949  1.139761
# 15  1.149252  1.455886
# 16  1.190105  1.489407
# 17  1.026498  1.153031
# 18  1.110015  1.329586
# 19  1.077741  1.277995

# %%
sample.groupby('x').mean()
# Out:
#                  y
# x
# 0.971699  0.977604
# 0.996044  0.997308
# 1.026498  1.153031
# 1.037332  0.977393
# 1.051670  1.040798
# 1.062949  1.139761
# 1.068022  1.173479
# 1.077741  1.277995
# 1.080161  1.191159
# 1.102914  1.127956
# 1.105722  1.320945
# 1.110015  1.329586
# 1.125997  1.293024
# 1.131291  1.294706
# 1.143305  1.412850
# 1.149252  1.455886
# 1.158193  1.480131
# 1.161464  1.344481
# 1.164161  1.431070
# 1.190105  1.489407

# %%
sample['x'].value_counts()
# Out:
# 1.105722    1
# 1.158193    1
# 1.110015    1
# 1.026498    1
# 1.190105    1
# 1.149252    1
# 1.062949    1
# 1.143305    1
# 0.996044    1
# 1.080161    1
# 1.161464    1
# 1.164161    1
# 1.102914    1
# 0.971699    1
# 1.051670    1
# 1.037332    1
# 1.125997    1
# 1.131291    1
# 1.068022    1
# 1.077741    1
# Name: x, dtype: int64

# %%
(sample['x'] > 0).value_counts()
# Out:
# False    20
# Name: x, dtype: int64

# %%
sample.describe()
# Out:
#                x          y
# count  20.000000  20.000000
# mean    1.095727   1.245429
# std     0.059538   0.168333
# min     0.971699   0.977393
# 25%     1.060129   1.136810
# 50%     1.104318   1.285509
# 75%     1.144792   1.361573
# max     1.190105   1.489407

# %%
sample.plot.scatter(x='x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sample.plot()
# Out:
# <AxesSubplot:>

# %%
sample.plot.bar()
# Out:
# <AxesSubplot:>

# %%
sample.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sample.corr()
# Out:
#           x         y
# x  1.000000  0.919912
# y  0.919912  1.000000

# %%
world_data = pd.read_csv('WorldBank-ATM.CO2E.PC_DS2.csv', index_col=0)
world_data
# Out:
#              ABW       AFE       AFG       AFW       AGO       ALB       AND  \
# Year
# 1960  204.631696  0.906060  0.046057  0.090880  0.100835  1.258195       NaN
# 1961  208.837879  0.922474  0.053589  0.095283  0.082204  1.374186       NaN
# 1962  226.081890  0.930816  0.073721  0.096612  0.210533  1.439956       NaN
# 1963  214.785217  0.940570  0.074161  0.112376  0.202739  1.181681       NaN
# 1964  207.626699  0.996033  0.086174  0.133258  0.213562  1.111742       NaN
# 1965  185.213644  1.047280  0.101285  0.184803  0.205891  1.166099       NaN
# 1966  172.158729  1.033908  0.107399  0.193676  0.268937  1.333055       NaN
# 1967  210.819017  1.052204  0.123409  0.189305  0.172096  1.363746       NaN
# 1968  194.917536  1.079727  0.115142  0.143989  0.289702  1.519551       NaN
# 1969  253.544574  1.104632  0.086510  0.202129  0.480199  1.558968       NaN
# 1970  281.962316  1.123261  0.149651  0.302643  0.608224  1.753240       NaN
# ...

# %%
world_data.head()
# Out:
#              ABW       AFE       AFG       AFW       AGO       ALB  AND  \
# Year
# 1960  204.631696  0.906060  0.046057  0.090880  0.100835  1.258195  NaN
# 1961  208.837879  0.922474  0.053589  0.095283  0.082204  1.374186  NaN
# 1962  226.081890  0.930816  0.073721  0.096612  0.210533  1.439956  NaN
# 1963  214.785217  0.940570  0.074161  0.112376  0.202739  1.181681  NaN
# 1964  207.626699  0.996033  0.086174  0.133258  0.213562  1.111742  NaN
#
#            ARB       ARE       ARG  ...  VIR       VNM       VUT       WLD  \
# Year                                ...
# 1960  0.609268  0.119037  2.383343  ...  NaN  0.181947       NaN  3.121158
# 1961  0.662618  0.109136  2.458551  ...  NaN  0.183099       NaN  3.068090
# 1962  0.727117  0.163542  2.538447  ...  NaN  0.217694  0.595002  3.114839
# 1963  0.853116  0.175833  2.330685  ...  NaN  0.196997  0.471849  3.221195
# 1964  0.972381  0.132815  2.553442  ...  NaN  0.209870  0.864427  3.324046
#
# ...

# %%
world_data.describe()
# Out:
#               ABW        AFE        AFG        AFW        AGO        ALB  \
# count   30.000000  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   184.079829   1.089405   0.149382   0.440692   0.687540   1.660433
# std     84.724762   0.157525   0.085583   0.147548   0.329161   0.643504
# min      2.868274   0.900399   0.037055   0.090880   0.082204   0.470098
# 25%    169.081608   0.971170   0.073941   0.443857   0.476051   1.258155
# 50%    199.774616   1.033908   0.149651   0.476438   0.640966   1.572251
# 75%    232.217652   1.188124   0.207444   0.515941   0.912209   2.001541
# max    360.853233   1.431964   0.407074   0.648273   1.285365   2.898209
#
#              AND        ARB         ARE        ARG  ...  VIR        VNM  \
# count  29.000000  59.000000   59.000000  59.000000  ...  0.0  59.000000
# mean    6.778152   2.923164   30.416576   3.544621  ...  NaN   0.716099
# std     0.688945   1.089531   20.916706   0.512579  ...  NaN   0.652798
# ...

# %%
world_data.isnull().any()
# Out:
# ABW     True
# AFE    False
# AFG    False
# AFW    False
# AGO    False
#        ...
# XKX     True
# YEM    False
# ZAF    False
# ZMB     True
# ZWE     True
# Length: 266, dtype: bool

# %%
world_data['USA'].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
world_data['USA'].plot(title='Capita in USA',ylabel='capita per year', ylim=0)
# Out:
# <AxesSubplot:title={'center':'Capita in USA'}, xlabel='Year', ylabel='capita per year'>

# %%
world_data[['USA', 'AND']].plot(ylim=0)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
world_data[['USA', 'ARE']].plot(ylim=0)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
world_data[['USA','WSM']].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
world_data[['ARE', 'ZWE']].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
world_data[['ABW', 'AFE']].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
world_data[['WLD', 'USA']].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
world_data[['USA', 'WLD', 'WSM']].plot(figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # Plotting Bar

# %%
world_data['USA'].plot.bar(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
world_data[['USA', 'WLD']].plot.bar(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
world_data[['USA', 'ARB']].loc[2010:].plot.bar(ylabel='capita per year', figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Year', ylabel='capita per year'>

# %% [markdown]
# # Histogram

# %%
world_data['USA'].plot.hist(figsize=(10, 5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
world_data['AND'].plot.hist(bins=5, figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Pie charts

# %%
df = pd.Series(data=[3, 5, 7], index=['a', 'b', 'c'])
df.plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
(world_data['USA'] < 17.5).value_counts().plot.pie(colors=['r', 'g'], labels=['>=17.5', '<17.5'], title='CO2 per capita', autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'CO2 per capita'}, ylabel='USA'>

# %%
ax = data.loc[year].plot.hist(bins=15, facecolor='green')

ax.set_xlabel('CO2 per capita')
ax.set_ylabel('Number of countries')
ax.annotate("USA", xy=(15, 5), xytext=(15, 30), 
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"))
